# %% [markdown]
# # Imports, Loading Pictures, Hyperparameters, One-Hot Encoding and Augmentation

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q keras
import keras
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import time
import seaborn as sns
import tensorflow as tf
from keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from imutils import paths
from PIL import Image

print("[INFO] loading images...")
data = []
labels = []
incorrect_mask_path = '/content/drive/MyDrive/Colab Notebooks/dataset/incorrect_mask'
with_mask_path = '/content/drive/MyDrive/Colab Notebooks/dataset/with_mask'
without_mask_path = '/content/drive/MyDrive/Colab Notebooks/dataset/without_mask'
for f in os.listdir(incorrect_mask_path):
  image = load_img(os.path.join(incorrect_mask_path, f), target_size=(224, 224))
  image = img_to_array(image)
  image = preprocess_input(image)
  data.append(image)
  labels.append(0)
for f in os.listdir(with_mask_path):
  image = load_img(os.path.join(with_mask_path, f), target_size=(224, 224))
  image = img_to_array(image)
  image = preprocess_input(image)
  data.append(image)
  labels.append(1)
for f in os.listdir(without_mask_path):
  image = load_img(os.path.join(without_mask_path, f), target_size=(224, 224))
  image = img_to_array(image)
  image = preprocess_input(image)
  data.append(image)
  labels.append(2)

INIT_LR = 1e-4   # initial learning rate
EPOCHS = 20      # number of epochs to train for
BS = 32          # batch size

data = np.array(data, dtype="float32")   # convert the data and labels to NumPy arrays
labels = np.array(labels)
lb = LabelEncoder()                      # perform one-hot encoding on the labels
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
labels = labels.astype(dtype = np.uint8)

aug = ImageDataGenerator(
	rotation_range=20,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="constant")

# %tensorflow_version 2.x
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mounted at /content/drive
# [INFO] loading images...
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Found GPU at: /device:GPU:0
# Mon May 17 07:41:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# ...

# %% [markdown]
# # MobileNetV2 Training, Testing and Heatmap

# %%
from tensorflow.keras.layers import BatchNormalization

(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = MobileNetV2(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = BatchNormalization()(headModel)
headModel = Dense(2048, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(3, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_mobnetv2.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for MobileNetV2', fontsize = 20) # title with fontsize 20


try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_mobnetv2.png', dpi=400)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 19s 244ms/step - loss: 0.6352 - accuracy: 0.7278 - val_loss: 0.2742 - val_accuracy: 0.8920
# Epoch 2/20
# 70/70 [==============================] - 16s 233ms/step - loss: 0.2504 - accuracy: 0.9029 - val_loss: 0.1990 - val_accuracy: 0.9168
# Epoch 3/20
# 70/70 [==============================] - 16s 234ms/step - loss: 0.2042 - accuracy: 0.9172 - val_loss: 0.1573 - val_accuracy: 0.9310
# Epoch 4/20
# 70/70 [==============================] - 16s 234ms/step - loss: 0.1600 - accuracy: 0.9479 - val_loss: 0.1591 - val_accuracy: 0.9239
# Epoch 5/20
# 70/70 [==============================] - 16s 235ms/step - loss: 0.1226 - accuracy: 0.9605 - val_loss: 0.1579 - val_accuracy: 0.9257
# Epoch 6/20
# 70/70 [==============================] - 16s 232ms/step - loss: 0.1356 - accuracy: 0.9420 - val_loss: 0.1416 - val_accuracy: 0.9363
# Epoch 7/20
# ...

# %% [markdown]
# # MobileNetV2 Plots

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for MobileNetV2")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_mobnetv2.png')

# %% [markdown]
# # ResNet50 V2

# %%
from tensorflow.keras.applications import ResNet50V2
from keras.layers import GlobalAveragePooling2D

(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = ResNet50V2(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

# flatten the output of the convolutional part: 
headModel = baseModel.output
headModel = GlobalAveragePooling2D()(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dropout(0.7)(headModel)
headModel = Dense(3, activation="softmax")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_resnet50v2.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for ResNet50V2', fontsize = 20) # title with fontsize 20
try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_resnet50v2.png', dpi=400)
# Out:
# ...
# 94674944/94668760 [==============================] - 1s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 21s 263ms/step - loss: 2.2570 - accuracy: 0.3090 - val_loss: 1.1325 - val_accuracy: 0.4956
# Epoch 2/20
# 70/70 [==============================] - 17s 249ms/step - loss: 1.4773 - accuracy: 0.4749 - val_loss: 0.8371 - val_accuracy: 0.6336
# Epoch 3/20
# 70/70 [==============================] - 17s 247ms/step - loss: 1.2058 - accuracy: 0.5614 - val_loss: 0.6484 - val_accuracy: 0.7274
# Epoch 4/20
# 70/70 [==============================] - 17s 245ms/step - loss: 0.9944 - accuracy: 0.6242 - val_loss: 0.5548 - val_accuracy: 0.7699
# Epoch 5/20
# 70/70 [==============================] - 17s 247ms/step - loss: 0.9156 - accuracy: 0.6475 - val_loss: 0.4851 - val_accuracy: 0.8053
# Epoch 6/20
# ...

# %% [markdown]
# # ResNet50 V2 Plots

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for ResNet50V2")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_resnet50v2.png')

# %% [markdown]
# # VGG 16

# %%
from tensorflow.keras.applications import VGG16

(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = VGG16(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

# flatten the output of the convolutional part: 
headModel = baseModel.output
headModel = Dropout(0.5)(headModel)
headModel = Flatten(name="flatten")(headModel)
# three hidden layers
headModel = Dense(100, activation="relu")(headModel)
headModel = Dense(100, activation="relu")(headModel)
headModel = Dense(100, activation="relu")(headModel)
# final softmax layer with two categories (dog and cat)
headModel = Dense(3, activation="softmax")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)


for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_vgg16.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for VGG16', fontsize = 20) # title with fontsize 20
try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_vgg16.png', dpi=400)
# Out:
# ...
# 58892288/58889256 [==============================] - 0s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 28s 351ms/step - loss: 0.9425 - accuracy: 0.5233 - val_loss: 0.4203 - val_accuracy: 0.8106
# Epoch 2/20
# 70/70 [==============================] - 18s 252ms/step - loss: 0.4452 - accuracy: 0.8090 - val_loss: 0.2929 - val_accuracy: 0.8938
# Epoch 3/20
# 70/70 [==============================] - 18s 251ms/step - loss: 0.3582 - accuracy: 0.8580 - val_loss: 0.3169 - val_accuracy: 0.8690
# Epoch 4/20
# 70/70 [==============================] - 18s 252ms/step - loss: 0.2809 - accuracy: 0.8914 - val_loss: 0.2160 - val_accuracy: 0.9204
# Epoch 5/20
# 70/70 [==============================] - 18s 255ms/step - loss: 0.2604 - accuracy: 0.9050 - val_loss: 0.2066 - val_accuracy: 0.9186
# Epoch 6/20
# ...

# %% [markdown]
# # VGG 16 Plots

# %%
EPOCHS = 20
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for VGG16")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_vgg16.png')

# %% [markdown]
# # Inception V3

# %%
from tensorflow.keras.applications import InceptionV3

(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = InceptionV3(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(1024, activation="relu")(headModel)
headModel = Dropout(0.2)(headModel)
headModel = Dense(3, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_inceptionv3.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for InceptionV3', fontsize = 20) # title with fontsize 20
try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_inceptionv3.png', dpi=400)
# Out:
# ...
# 87916544/87910968 [==============================] - 0s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 23s 269ms/step - loss: 3.4836 - accuracy: 0.6385 - val_loss: 0.2686 - val_accuracy: 0.8814
# Epoch 2/20
# 70/70 [==============================] - 17s 244ms/step - loss: 0.2765 - accuracy: 0.8900 - val_loss: 0.2362 - val_accuracy: 0.9186
# Epoch 3/20
# 70/70 [==============================] - 17s 242ms/step - loss: 0.2415 - accuracy: 0.9066 - val_loss: 0.2416 - val_accuracy: 0.9133
# Epoch 4/20
# 70/70 [==============================] - 17s 242ms/step - loss: 0.2073 - accuracy: 0.9181 - val_loss: 0.1765 - val_accuracy: 0.9416
# Epoch 5/20
# 70/70 [==============================] - 17s 243ms/step - loss: 0.2136 - accuracy: 0.9240 - val_loss: 0.2087 - val_accuracy: 0.9168
# Epoch 6/20
# ...

# %% [markdown]
# # Inception V3 Plots

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for InceptionV3")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_inceptionv3.png')

# %% [markdown]
# # Inception ResNet V2

# %%
from tensorflow.keras.applications import InceptionResNetV2

(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = InceptionResNetV2(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
# headModel = Dropout(0.5)(headModel)
headModel = Dense(3, activation="softmax")(headModel)

model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_inceptionresnetv2.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for InceptionV3', fontsize = 20) # title with fontsize 20
try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_inceptionresnetv2.png', dpi=400)
# Out:
# ...
# 219062272/219055592 [==============================] - 2s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 32s 315ms/step - loss: 1.0658 - accuracy: 0.7263 - val_loss: 0.2581 - val_accuracy: 0.8991
# Epoch 2/20
# 70/70 [==============================] - 19s 267ms/step - loss: 0.3022 - accuracy: 0.8856 - val_loss: 0.2120 - val_accuracy: 0.9239
# Epoch 3/20
# 70/70 [==============================] - 19s 265ms/step - loss: 0.2129 - accuracy: 0.9166 - val_loss: 0.2169 - val_accuracy: 0.9239
# Epoch 4/20
# 70/70 [==============================] - 19s 266ms/step - loss: 0.1999 - accuracy: 0.9247 - val_loss: 0.2011 - val_accuracy: 0.9292
# Epoch 5/20
# 70/70 [==============================] - 19s 266ms/step - loss: 0.1757 - accuracy: 0.9251 - val_loss: 0.1671 - val_accuracy: 0.9398
# Epoch 6/20
# ...

# %% [markdown]
# # Inception ResNet V2 Plots

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for InceptionResNetV2")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_inceptionresnetv2.png')

# %% [markdown]
# # DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.layers import BatchNormalization
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

baseModel = DenseNet121(weights="imagenet", include_top=False,
	input_shape= (224, 224, 3)) # ensure the head FC layer sets are left off

headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = BatchNormalization()(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.7)(headModel)
headModel = BatchNormalization()(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = BatchNormalization()(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(3, activation="softmax")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)

for layer in baseModel.layers:   # loop over all layers in the base model and freeze them so they will not be updated during the first training process
	layer.trainable = False

print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

early_stop = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=True)

print("[INFO] training head...")

H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS,
  callbacks=[early_stop])

start_time = time.time()
score = model.evaluate(testX, testY)
time_elapsed = time.time() - start_time
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Average inference time per image: {:.4f} (ms)'.format(1000*time_elapsed/len(testX)))

print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
predIdxs = np.argmax(predIdxs, axis=1)
testY = np.where(testY==1)[1]

print("[INFO] saving mask detector model...")
mydir = '/content/drive/MyDrive/Colab Notebooks/models'
try:
   if not os.path.exists(os.path.dirname(mydir)):
       os.makedirs(os.path.dirname(mydir))
except OSError as err:
   print(err)
model.save('/content/drive/MyDrive/Colab Notebooks/models/model_densenet121.h5')

print("[INFO] saving heatmap...")
print(metrics.confusion_matrix(testY, predIdxs))
fig, ax = plt.subplots(figsize=(10,10))
x_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for x-axis
y_axis_labels = ['Incorrect', 'With Mask', 'Without Mask'] # labels for y-axis
heat_map = sns.heatmap(metrics.confusion_matrix(testY, predIdxs, normalize='pred'), annot=True,  ax=ax, xticklabels=x_axis_labels, yticklabels=y_axis_labels)

mydir2 = '/content/drive/MyDrive/Colab Notebooks/Heatmaps'
plt.title('Mask Detection heatmap for DenseNet121', fontsize = 20) # title with fontsize 20
try:
  if not os.path.exists(os.path.dirname(mydir2)):
        os.makedirs(os.path.dirname(mydir2))
except OSError as err:
    print(err)
figure = heat_map.get_figure()    
figure.savefig('/content/drive/MyDrive/Colab Notebooks/Heatmaps/heatmap_densenet121.png', dpi=400)
# Out:
# ...
# 29089792/29084464 [==============================] - 0s 0us/step
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/20
# 70/70 [==============================] - 26s 281ms/step - loss: 1.8110 - accuracy: 0.3636 - val_loss: 0.5467 - val_accuracy: 0.7912
# Epoch 2/20
# 70/70 [==============================] - 17s 249ms/step - loss: 1.2405 - accuracy: 0.4921 - val_loss: 0.3841 - val_accuracy: 0.8832
# Epoch 3/20
# 70/70 [==============================] - 17s 246ms/step - loss: 1.0386 - accuracy: 0.5773 - val_loss: 0.3372 - val_accuracy: 0.8991
# Epoch 4/20
# 70/70 [==============================] - 17s 244ms/step - loss: 0.8742 - accuracy: 0.6293 - val_loss: 0.3089 - val_accuracy: 0.8973
# Epoch 5/20
# 70/70 [==============================] - 17s 246ms/step - loss: 0.7678 - accuracy: 0.6521 - val_loss: 0.2871 - val_accuracy: 0.8956
# Epoch 6/20
# ...

# %% [markdown]
# # DenseNet121 Plots

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy for DenseNet121")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
mydir = '/content/drive/MyDrive/Colab Notebooks/Plots'
try:
  if not os.path.exists(os.path.dirname(mydir)):
        os.makedirs(os.path.dirname(mydir))
except OSError as err:
    print(err)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Plots/plot_densenet121.png')
